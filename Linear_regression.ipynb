# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('/content/Linear_regression.csv')
x = df[['YearsExperience']]
y = df['Salary']
plt.scatter(x, y)
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
model = LinearRegression()  #here just intialize the parameters
model.fit(x_train, y_train)  #here use the formula of m,c and calculating value
y_pred = model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'R-squared: {r2}')
accuracy_score = model.score(x_test, y_test)
print(f'Accuracy Score: {accuracy_score}')
# Out:
# R-squared: 0.9024461774180497
# Accuracy Score: 0.9024461774180497

# %%
plt.scatter(x_test, y_test, color='blue', label='Actual')
plt.plot(x_test, y_pred, color='red', label='Predicted')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.legend()
